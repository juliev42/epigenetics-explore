# %%
import pandas as pd

# %%
ucec_meta = pd.read_csv('data/ucec_metadata.csv',index_col = 0)

# %%
ucec_meta.head(15)
# Out:
#     cases.0.demographic.age_at_index   cases.0.demographic.race  \
# 0                               61.0                      white
# 1                               67.0                      white
# 2                               76.0                      white
# 3                               69.0                      white
# 4                               78.0                      white
# 5                               70.0                      white
# 6                               77.0                      white
# 7                               69.0                      white
# 8                               67.0  black or african american
# 9                               90.0                      white
# 10                              90.0                      white
# 11                              65.0               not reported
# 12                              71.0                      white
# 13                              67.0                      white
# 14                              64.0                      white
#
#                       cases.0.disease_type cases.0.project.primary_site  \
# 0             Adenomas and Adenocarcinomas                       Uterus
# 1             Adenomas and Adenocarcinomas                       Uterus
# 2             Adenomas and Adenocarcinomas                       Uterus
# 3             Adenomas and Adenocarcinomas                       Uterus
# 4             Adenomas and Adenocarcinomas                       Uterus
# 5   "Cystic Mucinous and Serous Neoplasms"                       Uterus
# 6             Adenomas and Adenocarcinomas                       Uterus
# 7             Adenomas and Adenocarcinomas                       Uterus
# 8             Adenomas and Adenocarcinomas                       Uterus
# 9   "Cystic Mucinous and Serous Neoplasms"                       Uterus
# 10  "Cystic Mucinous and Serous Neoplasms"                       Uterus
# 11            Adenomas and Adenocarcinomas                       Uterus
# 12  "Cystic Mucinous and Serous Neoplasms"                       Uterus
# 13            Adenomas and Adenocarcinomas                       Uterus
# 14            Adenomas and Adenocarcinomas                       Uterus
#
#    cases.0.project.project_id cases.0.samples.0.sample_type  \
# 0                   TCGA-UCEC                 Primary Tumor
# 1                   TCGA-UCEC                 Primary Tumor
# 2                   TCGA-UCEC                 Primary Tumor
# 3                   TCGA-UCEC                 Primary Tumor
# 4                   TCGA-UCEC                 Primary Tumor
# 5                   TCGA-UCEC                 Primary Tumor
# 6                   TCGA-UCEC                 Primary Tumor
# 7                   TCGA-UCEC                 Primary Tumor
# 8                   TCGA-UCEC                 Primary Tumor
# 9                   TCGA-UCEC           Solid Tissue Normal
# 10                  TCGA-UCEC                 Primary Tumor
# 11                  TCGA-UCEC                 Primary Tumor
# 12                  TCGA-UCEC                 Primary Tumor
# 13                  TCGA-UCEC                 Primary Tumor
# 14                  TCGA-UCEC                 Primary Tumor
#
#    cases.0.submitter_id                                          file_name
# 0          TCGA-D1-A17H  e42a29e2-6d67-4dcb-8944-e61785cd623c.methylati...
# 1          TCGA-D1-A176  e963e769-6e56-4ff7-82ff-d3bd82b506fd.methylati...
# 2          TCGA-AX-A3G8  eb7c3516-d964-4f45-a906-631d8f14f774.methylati...
# 3          TCGA-AX-A3FX  bddcc282-2ffa-43f9-8dee-cfb85812c9b2.methylati...
# 4          TCGA-D1-A17C  9872b91f-1795-42c0-8420-bad7b7fffeba.methylati...
# 5          TCGA-D1-A2G0  f1c54ee2-0776-4565-9ba9-bc4630268464.methylati...
# 6          TCGA-AX-A2HK  0848b04f-38bd-4104-90c7-05b524ee7398.methylati...
# 7          TCGA-AJ-A23O  39818429-7891-4226-a5e4-5a4855296f10.methylati...
# 8          TCGA-EY-A1GR  1d799d3d-0d0c-4535-b55e-5f8bf75f8007.methylati...
# 9          TCGA-AJ-A3NH  b19b8903-7e11-48df-bdc2-6cbce58748df.methylati...
# 10         TCGA-AJ-A3NH  98e7cb53-858b-4d9b-b3f7-22b0591ea894.methylati...
# 11         TCGA-EO-A1Y7  45fb0566-ef15-458a-b0e2-166430f6cb13.methylati...
# 12         TCGA-AX-A3G7  b2c553e0-06f9-43a2-a57a-b6cf0f7d0ebb.methylati...
# 13         TCGA-A5-A0GA  c5c5cce3-854c-40b2-8635-ed3b262d02bb.methylati...
# 14         TCGA-AP-A056  ef370fad-6416-4e53-9bb8-db653f8766c9.methylati...

# %%
ucec_meta['cases.0.samples.0.sample_type'].value_counts()
# Out:
# Primary Tumor          555
# Solid Tissue Normal     47
# Recurrent Tumor          1
# Name: cases.0.samples.0.sample_type, dtype: int64

# %%
ucec_meta.columns = ['age', 'race', 'disease_type', 'primary_site', 'project_id','sample_type','submitter_id','methylation_file_id']

# %%
ucec_meta[ucec_meta['methylation_file_id']=="e42a29e2-6d67-4dcb-8944-e61785cd623c.methylation_array.sesame.level3betas.txt"]
# Out:
#     age   race                  disease_type primary_site project_id  \
# 0  61.0  white  Adenomas and Adenocarcinomas       Uterus  TCGA-UCEC
#
#      sample_type  submitter_id  \
# 0  Primary Tumor  TCGA-D1-A17H
#
#                                  methylation_file_id
# 0  e42a29e2-6d67-4dcb-8944-e61785cd623c.methylati...
