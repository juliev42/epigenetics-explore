# %%
import pandas as pd

# %%
ucec_meta = pd.read_csv('data/ucec_metadata.csv',index_col = 0)

# %%
ucec_meta.head(15)
# Out:
#      age                       race                            disease_type  \
# 0   61.0                      white            Adenomas and Adenocarcinomas
# 1   67.0                      white            Adenomas and Adenocarcinomas
# 2   76.0                      white            Adenomas and Adenocarcinomas
# 3   69.0                      white            Adenomas and Adenocarcinomas
# 4   78.0                      white            Adenomas and Adenocarcinomas
# 5   70.0                      white  "Cystic Mucinous and Serous Neoplasms"
# 6   77.0                      white            Adenomas and Adenocarcinomas
# 7   69.0                      white            Adenomas and Adenocarcinomas
# 8   67.0  black or african american            Adenomas and Adenocarcinomas
# 9   90.0                      white  "Cystic Mucinous and Serous Neoplasms"
# 10  90.0                      white  "Cystic Mucinous and Serous Neoplasms"
# ...

# %%
ucec_meta['cases.0.samples.0.sample_type'].value_counts()
# Out:
# Primary Tumor          555
# Solid Tissue Normal     47
# Recurrent Tumor          1
# Name: cases.0.samples.0.sample_type, dtype: int64

# %%
ucec_meta.columns = ['age', 'race', 'disease_type', 'primary_site', 'project_id','sample_type','submitter_id','methylation_file_id']

# %%
ucec_meta[ucec_meta['methylation_file_id']=="e42a29e2-6d67-4dcb-8944-e61785cd623c.methylation_array.sesame.level3betas.txt"]
# Out:
#     age   race                  disease_type primary_site project_id  \
# 0  61.0  white  Adenomas and Adenocarcinomas       Uterus  TCGA-UCEC
#
#      sample_type  submitter_id  \
# 0  Primary Tumor  TCGA-D1-A17H
#
#                                  methylation_file_id
# 0  e42a29e2-6d67-4dcb-8944-e61785cd623c.methylati...

# %%
ucec_meta.sample_type.value_counts()
# Out:
# Primary Tumor          555
# Solid Tissue Normal     47
# Recurrent Tumor          1
# Name: sample_type, dtype: int64
